# %%
"""
1. Who developed Python Programming Language? 
=> Guido van Rossum in 1991

2. Which type of Programming does Python support? 
=> It supports:
a) web development (server-side),
b) software development,
c) mathematics,
system scripting.

3. Is Python case sensitive when dealing with identifiers? 
=>Yes, it treats upper case and lower case in a different manner

4. What is the correct extension of the Python file? 
=>ipynb for jupyter. otherwise world widely, its .py

5. Is Python code compiled or interpreted? 
=>it is interpreted language so obviously the code gets interpreted means it gets converted into byte code by Python VM.

6. Name a few blocks of code used to define in Python language? 
=> module, class definition, function body

7. State a character used to give single-line comments in Python? 
=> Answer is #

8. Mention functions which can help us to find the version of python that we are currently working on? 
=> python_version()

9. Python supports the creation of anonymous functions at runtime, using a construct called 
=> Lambda

10. What does pip stand for python? 
=>preferred installer program

11. Mention a few built-in functions in python? 
print(), sum(), type(), input(), pow(), dir().... total 68 built in functions in python

12. What is the maximum possible length of an identifier in Python? 
==> 79 CHARACTERS

13. What are the benefits of using Python? 
=>Python works on different platforms (Windows, Mac, Linux, Raspberry Pi, etc).
Python has a simple syntax similar to the English language.
Python has syntax that allows developers to write programs with fewer lines than some other programming languages.
Python runs on an interpreter system, meaning that code can be executed as soon as it is written. This means that prototyping can be very quick.
Python can be treated in a procedural way, an object-oriented way or a functional way.

14. How is memory managed in Python? 
Memory management in Python involves a private heap containing all Python objects and data structures. The management of this private heap is ensured internally by the Python memory manager.

15. How to install Python on Windows and set path variables?
==>one can download it for free from the website: https://www.python.org/
To set path, follow https://www.javatpoint.com/how-to-set-python-path


16. Is indentation required in python? 
==> yes, it doesnt need curly braces for block start-end, rather it used identation to separate a block from one another
"""
